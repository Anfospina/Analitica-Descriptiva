# %%
import pandas as pd
import zipfile
import os

def clean_campaign_data():
    input_dir='../files/input/'
    #output_dir='files/output/'
    #os.makedirs(output_dir, exist_ok=True)
    
    client_data=[]
    #campaign_data=[]
    #economics_data=[]
    
    for file_name in os.listdir(input_dir):
        if file_name.endswith('.csv.zip'):
            with zipfile.ZipFile(input_dir+file_name, 'r') as z:
                for csv_file in z.namelist():
                    with z.open(csv_file) as f:
                        df=pd.read_csv(f)
                        if 'client_id' in df.columns:
                            client_data.append(df)


    return pd.concat(client_data)

h=clean_campaign_data()
h
# Out:
#       Unnamed: 0  client_id  age          job  marital            education  \
# 0              0          0   56    housemaid  married             basic.4y
# 1              1          1   57     services  married          high.school
# 2              2          2   37     services  married          high.school
# 3              3          3   40       admin.  married             basic.6y
# 4              4          4   56     services  married          high.school
# ...          ...        ...  ...          ...      ...                  ...
# 4113        4113      41183   73      retired  married  professional.course
# 4114        4114      41184   46  blue-collar  married  professional.course
# 4115        4115      41185   56      retired  married    university.degree
# 4116        4116      41186   44   technician  married  professional.course
# 4117        4117      41187   74      retired  married  professional.course
#
#      credit_default mortgage month  day  contact_duration  number_contacts  \
# 0                no       no   may   13               261                1
# 1           unknown       no   may   19               149                1
# 2                no      yes   may   23               226                1
# 3                no       no   may   27               151                1
# 4                no       no   may    3               307                1
# ...             ...      ...   ...  ...               ...              ...
# 4113             no      yes   nov   30               334                1
# 4114             no       no   nov    6               383                1
# 4115             no      yes   nov   24               189                2
# 4116             no       no   nov   17               442                1
# 4117             no      yes   nov   23               239                3
#
#       previous_campaign_contacts previous_outcome  cons_price_idx  \
# 0                              0      nonexistent          93.994
# 1                              0      nonexistent          93.994
# 2                              0      nonexistent          93.994
# 3                              0      nonexistent          93.994
# 4                              0      nonexistent          93.994
# ...                          ...              ...             ...
# 4113                           0      nonexistent          94.767
# 4114                           0      nonexistent          94.767
# 4115                           0      nonexistent          94.767
# 4116                           0      nonexistent          94.767
# 4117                           1          failure          94.767
#
#       euribor_three_months campaign_outcome
# 0                    4.857               no
# 1                    4.857               no
# 2                    4.857               no
# 3                    4.857               no
# 4                    4.857               no
# ...                    ...              ...
# 4113                 1.028              yes
# 4114                 1.028               no
# 4115                 1.028               no
# 4116                 1.028              yes
# 4117                 1.028               no
#
# [41188 rows x 17 columns]
